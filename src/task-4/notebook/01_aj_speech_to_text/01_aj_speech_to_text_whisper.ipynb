# %% [markdown]
# ### Whisper

# %% [markdown]
# ### Installation (if required)

# %%
# !pip install gdown

# %%
import torch
from transformers import pipeline
from transformers import WhisperProcessor, WhisperForConditionalGeneration

# %% [markdown]
# ### Download sample video

# %%
# sample 1 min audio
# ref: https://www.youtube.com/watch?v=aukXofc_8mM

# !gdown https://drive.google.com/uc?id=1T1XD1Sfl7QUl-9kzL7Z7fDq-m97TYAr6
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1T1XD1Sfl7QUl-9kzL7Z7fDq-m97TYAr6
# To: /content/1.mp3
# 100% 1.51M/1.51M [00:00<00:00, 61.8MB/s]

# %%
whisper  = pipeline("automatic-speech-recognition", "openai/whisper-medium", device="cuda:0") # if you don't have GPU, remove this argument
# Out:
# config.json:   0%|          | 0.00/1.99k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.06G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/3.69k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/805 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/836k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.48M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/494k [00:00<?, ?B/s]
# normalizer.json:   0%|          | 0.00/52.7k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/34.6k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.08k [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# preprocessor_config.json:   0%|          | 0.00/185k [00:00<?, ?B/s]

# %%
# %%time
transcription = whisper("1.mp3", chunk_length_s=30)
# Out:
# CPU times: user 7.89 s, sys: 279 ms, total: 8.17 s
# Wall time: 8.97 s

# %%
transcription["text"]
# Out:
# " Hi guys, welcome back to One Minute Wednesdays the video where I teach you English in just one minute you Solidify your knowledge by writing a practice sentence down in the comment section below if you're right I'll give you a thumb up and if you're not I will try to correct you. So let's start that clock So in today's lesson, we are looking at the words feet and feet Two words that sound exactly the same because they're homophones but they're spelt differently and they have different meanings. The first feet this is a great achievement that requires skill strength and courage for example walking on the moon was a great feat for humanity. Next we have the word feet. This is the plural form of the word foot and a foot is this. It's your lower extremity on which you stand. So I might say her feet were cold from walking barefoot."

# %%
import IPython
IPython.display.Audio("1.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from IPython.display import HTML

HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/aukXofc_8mM" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# /home/lenovo/Alphin/omdena/myenv/lib/python3.10/site-packages/IPython/core/display.py:431: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe width="560" height="315" src="https://www.youtube.com/embed/aukXofc_8mM" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# ### Reference:
# * https://huggingface.co/openai/whisper-large
# * https://github.com/openai/whisper
