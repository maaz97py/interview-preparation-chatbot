# %% [markdown]
# ## gTTS

# %% [markdown]
# ### Installation (if required)

# %%
# !pip3 install gTTS
# Out:
# Collecting gTTS
#   Downloading gTTS-2.4.0-py3-none-any.whl (29 kB)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.10/dist-packages (from gTTS) (2.31.0)
# Requirement already satisfied: click<8.2,>=7.1 in /usr/local/lib/python3.10/dist-packages (from gTTS) (8.1.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gTTS) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gTTS) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gTTS) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gTTS) (2023.11.17)
# Installing collected packages: gTTS
# Successfully installed gTTS-2.4.0

# %% [markdown]
# ### Reference:
# https://pypi.org/project/gTTS/

# %%
from gtts import gTTS
t = """I apologize for the confusion. As of my last update in January 2022, OpenAI's models, including Whisper, were not available through the Hugging Face transformers library.
        If you're specifically looking for OpenAI's Whisper model, you should check OpenAI's official documentation or resources for the correct way to use it.
      OpenAI might provide its models through its own API or other means.For the most accurate and up-to-date information"""

# %%
tts = gTTS(t)

# %%
tts.save('hello.mp3')

# %%
import IPython
IPython.display.Audio("hello.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Listen without saving file

# %%
from tempfile import TemporaryFile
from IPython.display import Audio

# %%
tts = gTTS(t)

# %%
f = TemporaryFile()

# %%
tts.write_to_fp(f)

# %%
f.seek(0)
Audio(f.read(), autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
f.close()

# %% [markdown]
# # pyttsx3

# %% [markdown]
# ### Installation (if required)

# %%
# !pip install pyttsx3

# %% [markdown]
# Please note that if any errors arise, check the following libraries are installed using either pip or apt (for Ubuntu):
#
# ```
# sudo apt install espeak
# pip3 install pyaudio
# sudo apt install python3-pyaudio
# ```
#
# This will help resolve any dependencies or issues that may arise during the execution of the code.

# %% [markdown]
# ### Reference:
# https://pypi.org/project/pyttsx3/

# %%
import pyttsx3

# %%
t = """I apologize for the confusion. As of my last update in January 2022, OpenAI's models, including Whisper, were not available through the Hugging Face transformers library.
        If you're specifically looking for OpenAI's Whisper model, you should check OpenAI's official documentation or resources for the correct way to use it.
      OpenAI might provide its models through its own API or other means.For the most accurate and up-to-date information"""

# %%
rate = engine.getProperty('rate')   # getting details of current speaking rate
print (rate)                        #printing current voice rate
engine.setProperty('rate', 125)
# Out:
# 175

# %%
engine = pyttsx3.init()
engine.say(t)
engine.runAndWait()

# %% [markdown]
# ### test speakers

# %%
voices = engine.getProperty('voices')
i = 0
for voice in voices:
    print(i, voice, voice.id)
    engine.setProperty('voice', voice.id)
    engine.say("Hello World!")
    engine.runAndWait()
    engine.stop()
    i += 1
# Out:
# 0 <Voice id=afrikaans
#           name=afrikaans
#           languages=[b'\x05af']
#           gender=male
#           age=None> afrikaans
# 1 <Voice id=aragonese
#           name=aragonese
#           languages=[b'\x05an']
#           gender=male
#           age=None> aragonese
# 2 <Voice id=bulgarian
#           name=bulgarian
#           languages=[b'\x05bg']
#           gender=None
#           age=None> bulgarian
# 3 <Voice id=bengali
#           name=bengali
#           languages=[b'\x05bn']
#           gender=male
#           age=None> bengali
# 4 <Voice id=bosnian
#           name=bosnian
#           languages=[b'\x05bs']
#           gender=male
#           age=None> bosnian
# 5 <Voice id=catalan
#           name=catalan
#           languages=[b'\x05ca']
#           gender=male
#           age=None> catalan
# 6 <Voice id=czech
#           name=czech
#           languages=[b'\x05cs']
#           gender=male
#           age=None> czech
# 7 <Voice id=welsh
#           name=welsh
#           languages=[b'\x05cy']
#           gender=male
#           age=None> welsh
# 8 <Voice id=danish
#           name=danish
#           languages=[b'\x05da']
#           gender=male
#           age=None> danish
# 9 <Voice id=german
#           name=german
#           languages=[b'\x05de']
#           gender=male
#           age=None> german
# 10 <Voice id=greek
#           name=greek
#           languages=[b'\x05el']
#           gender=male
#           age=None> greek
# 11 <Voice id=default
#           name=default
#           languages=[b'\x05en']
#           gender=male
#           age=None> default
# 12 <Voice id=english
#           name=english
#           languages=[b'\x02en-gb']
#           gender=male
#           age=None> english
# 13 <Voice id=en-scottish
#           name=en-scottish
#           languages=[b'\x05en-sc']
#           gender=male
#           age=None> en-scottish
# 14 <Voice id=english-north
#           name=english-north
#           languages=[b'\x05en-uk-north']
#           gender=male
#           age=None> english-north
# 15 <Voice id=english_rp
#           name=english_rp
#           languages=[b'\x05en-uk-rp']
#           gender=male
#           age=None> english_rp
# 16 <Voice id=english_wmids
#           name=english_wmids
#           languages=[b'\x05en-uk-wmids']
#           gender=male
#           age=None> english_wmids
# 17 <Voice id=english-us
#           name=english-us
#           languages=[b'\x02en-us']
#           gender=male
#           age=None> english-us
# 18 <Voice id=en-westindies
#           name=en-westindies
#           languages=[b'\x05en-wi']
#           gender=male
#           age=None> en-westindies
# 19 <Voice id=esperanto
#           name=esperanto
#           languages=[b'\x05eo']
#           gender=male
#           age=None> esperanto
# 20 <Voice id=spanish
#           name=spanish
#           languages=[b'\x05es']
#           gender=male
#           age=None> spanish
# 21 <Voice id=spanish-latin-am
#           name=spanish-latin-am
#           languages=[b'\x05es-la']
#           gender=male
#           age=None> spanish-latin-am
# 22 <Voice id=estonian
#           name=estonian
#           languages=[b'\x05et']
#           gender=None
#           age=None> estonian
# 23 <Voice id=basque-test
#           name=basque-test
#           languages=[b'\x05eu']
#           gender=None
#           age=None> basque-test
# 24 <Voice id=Persian+English-UK
#           name=Persian+English-UK
#           languages=[b'\x05fa']
#           gender=None
#           age=None> Persian+English-UK
# 25 <Voice id=Persian+English-US
#           name=Persian+English-US
#           languages=[b'\x05fa']
#           gender=None
#           age=None> Persian+English-US
# 26 <Voice id=persian-pinglish
#           name=persian-pinglish
#           languages=[b'\x05fa-pin']
#           gender=None
#           age=None> persian-pinglish
# 27 <Voice id=finnish
#           name=finnish
#           languages=[b'\x05fi']
#           gender=male
#           age=None> finnish
# 28 <Voice id=french-Belgium
#           name=french-Belgium
#           languages=[b'\x05fr-be']
#           gender=male
#           age=None> french-Belgium
# 29 <Voice id=french
#           name=french
#           languages=[b'\x05fr-fr']
#           gender=male
#           age=None> french
# 30 <Voice id=irish-gaeilge
#           name=irish-gaeilge
#           languages=[b'\x05ga']
#           gender=None
#           age=None> irish-gaeilge
# 31 <Voice id=greek-ancient
#           name=greek-ancient
#           languages=[b'\x05grc']
#           gender=male
#           age=None> greek-ancient
# 32 <Voice id=gujarati-test
#           name=gujarati-test
#           languages=[b'\x05gu']
#           gender=None
#           age=None> gujarati-test
# 33 <Voice id=hindi
#           name=hindi
#           languages=[b'\x05hi']
#           gender=male
#           age=None> hindi
# 34 <Voice id=croatian
#           name=croatian
#           languages=[b'\x05hr']
#           gender=male
#           age=None> croatian
# 35 <Voice id=hungarian
#           name=hungarian
#           languages=[b'\x05hu']
#           gender=male
#           age=None> hungarian
# 36 <Voice id=armenian
#           name=armenian
#           languages=[b'\x05hy']
#           gender=male
#           age=None> armenian
# 37 <Voice id=armenian-west
#           name=armenian-west
#           languages=[b'\x05hy-west']
#           gender=male
#           age=None> armenian-west
# 38 <Voice id=interlingua
#           name=interlingua
#           languages=[b'\x05ia']
#           gender=None
#           age=None> interlingua
# 39 <Voice id=indonesian
#           name=indonesian
#           languages=[b'\x05id']
#           gender=male
#           age=None> indonesian
# 40 <Voice id=icelandic
#           name=icelandic
#           languages=[b'\x05is']
#           gender=male
#           age=None> icelandic
# 41 <Voice id=italian
#           name=italian
#           languages=[b'\x05it']
#           gender=male
#           age=None> italian
# 42 <Voice id=lojban
#           name=lojban
#           languages=[b'\x05jbo']
#           gender=None
#           age=None> lojban
# 43 <Voice id=georgian
#           name=georgian
#           languages=[b'\x05ka']
#           gender=None
#           age=None> georgian
# 44 <Voice id=kannada
#           name=kannada
#           languages=[b'\x05kn']
#           gender=None
#           age=None> kannada
# 45 <Voice id=kurdish
#           name=kurdish
#           languages=[b'\x05ku']
#           gender=male
#           age=None> kurdish
# 46 <Voice id=latin
#           name=latin
#           languages=[b'\x05la']
#           gender=male
#           age=None> latin
# 47 <Voice id=lingua_franca_nova
#           name=lingua_franca_nova
#           languages=[b'\x05lfn']
#           gender=male
#           age=None> lingua_franca_nova
# 48 <Voice id=lithuanian
#           name=lithuanian
#           languages=[b'\x05lt']
#           gender=male
#           age=None> lithuanian
# 49 <Voice id=latvian
#           name=latvian
#           languages=[b'\x05lv']
#           gender=male
#           age=None> latvian
# 50 <Voice id=macedonian
#           name=macedonian
#           languages=[b'\x05mk']
#           gender=male
#           age=None> macedonian
# 51 <Voice id=malayalam
#           name=malayalam
#           languages=[b'\x05ml']
#           gender=male
#           age=None> malayalam
# 52 <Voice id=malay
#           name=malay
#           languages=[b'\x05ms']
#           gender=male
#           age=None> malay
# 53 <Voice id=nepali
#           name=nepali
#           languages=[b'\x05ne']
#           gender=male
#           age=None> nepali
# aplay: pcm_write:2127: write error: Interrupted system call
# 54 <Voice id=dutch
#           name=dutch
#           languages=[b'\x05nl']
#           gender=male
#           age=None> dutch
# aplay: pcm_write:2127: write error: Interrupted system call
# 55 <Voice id=norwegian
#           name=norwegian
#           languages=[b'\x05no']
#           gender=male
#           age=None> norwegian
# aplay: pcm_write:2127: write error: Interrupted system call
# 56 <Voice id=punjabi
#           name=punjabi
#           languages=[b'\x05pa']
#           gender=None
#           age=None> punjabi
# aplay: pcm_write:2127: write error: Interrupted system call
# aplay: pcm_write:2127: write error: Interrupted system call
# 57 <Voice id=polish
#           name=polish
#           languages=[b'\x05pl']
#           gender=male
#           age=None> polish
# 58 <Voice id=brazil
#           name=brazil
#           languages=[b'\x05pt-br']
#           gender=male
#           age=None> brazil
# aplay: pcm_write:2127: write error: Interrupted system call
# aplay: pcm_write:2127: write error: Interrupted system call
# 59 <Voice id=portugal
#           name=portugal
#           languages=[b'\x05pt-pt']
#           gender=male
#           age=None> portugal
# 60 <Voice id=romanian
#           name=romanian
#           languages=[b'\x05ro']
#           gender=male
#           age=None> romanian
# aplay: pcm_write:2127: write error: Interrupted system call
# Full dictionary is not installed for 'ru'
# aplay: pcm_write:2127: write error: Interrupted system call
# 61 <Voice id=russian
#           name=russian
#           languages=[b'\x05ru']
#           gender=male
#           age=None> russian
# 62 <Voice id=slovak
#           name=slovak
#           languages=[b'\x05sk']
#           gender=male
#           age=None> slovak
# aplay: pcm_write:2127: write error: Interrupted system call
# aplay: pcm_write:2127: write error: Interrupted system call
# 63 <Voice id=albanian
#           name=albanian
#           languages=[b'\x05sq']
#           gender=male
#           age=None> albanian
# 64 <Voice id=serbian
#           name=serbian
#           languages=[b'\x05sr']
#           gender=male
#           age=None> serbian
# aplay: pcm_write:2127: write error: Interrupted system call
# aplay: pcm_write:2127: write error: Interrupted system call
# 65 <Voice id=swedish
#           name=swedish
#           languages=[b'\x05sv']
#           gender=male
#           age=None> swedish
# 66 <Voice id=swahili-test
#           name=swahili-test
#           languages=[b'\x05sw']
#           gender=male
#           age=None> swahili-test
# aplay: pcm_write:2127: write error: Interrupted system call
# aplay: pcm_write:2127: write error: Interrupted system call
# 67 <Voice id=tamil
#           name=tamil
#           languages=[b'\x05ta']
#           gender=male
#           age=None> tamil
# 68 <Voice id=telugu-test
#           name=telugu-test
#           languages=[b'\x05te']
#           gender=None
#           age=None> telugu-test
# aplay: pcm_write:2127: write error: Interrupted system call
# aplay: pcm_write:2127: write error: Interrupted system call
# 69 <Voice id=turkish
#           name=turkish
#           languages=[b'\x05tr']
#           gender=male
#           age=None> turkish
# 70 <Voice id=vietnam
#           name=vietnam
#           languages=[b'\x05vi']
#           gender=male
#           age=None> vietnam
# aplay: pcm_write:2127: write error: Interrupted system call
# aplay: pcm_write:2127: write error: Interrupted system call
# 71 <Voice id=vietnam_hue
#           name=vietnam_hue
#           languages=[b'\x05vi-hue']
#           gender=male
#           age=None> vietnam_hue
# 72 <Voice id=vietnam_sgn
#           name=vietnam_sgn
#           languages=[b'\x05vi-sgn']
#           gender=male
#           age=None> vietnam_sgn
# aplay: pcm_write:2127: write error: Interrupted system call
# aplay: pcm_write:2127: write error: Interrupted system call
# Full dictionary is not installed for 'zhy'
# 73 <Voice id=Mandarin
#           name=Mandarin
#           languages=[b'\x05zh']
#           gender=male
#           age=None> Mandarin
# 74 <Voice id=cantonese
#           name=cantonese
#           languages=[b'\x05zh-yue']
#           gender=male
#           age=None> cantonese
# aplay: pcm_write:2127: write error: Interrupted system call
